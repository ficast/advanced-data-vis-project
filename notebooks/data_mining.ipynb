# %%
import pandas as pd

# %%
df = pd.read_csv("../project/MICRODADOS_ENEM_2015.csv", encoding="ISO-8859-1", sep=";")
df.head()
# Out:
#    NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0  150000000376    2015               14       M              1.0
# 1  150000003053    2015                6       M              0.0
# 2  150000001161    2015                7       M              1.0
# 3  150000001335    2015                8       F              0.0
# 4  150000001219    2015                3       M              0.0
#
#    TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  TP_ESCOLA  \
# 0            1                 1                1               10          1
# 1            3                 1                1                5          1
# 2            2                 1                4                0          1
# 3            4                 1                1                6          1
# 4            3                 1                1                2          1
#
#    ...  Q041  Q042  Q043 Q044  Q045 Q046  Q047  Q048  Q049  Q050
# ...

# %%
columns = []
for col in df.columns:
    columns.append(col)

print(columns)
# Out:
# ['NU_ANO', 'TP_FAIXA_ETARIA', 'TP_SEXO', 'TP_ESTADO_CIVIL', 'TP_COR_RACA', 'TP_NACIONALIDADE', 'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO', 'IN_TREINEIRO', 'NO_MUNICIPIO_ESC', 'SG_UF_ESC', 'TP_DEPENDENCIA_ADM_ESC', 'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC', 'NO_MUNICIPIO_PROVA', 'SG_UF_PROVA', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC', 'NU_NOTA_MT', 'NU_NOTA_REDACAO', 'Q001', 'Q002', 'Q003', 'Q004', 'Q005', 'Q006', 'Q007', 'Q008', 'Q009', 'Q010', 'Q011', 'Q012', 'Q013', 'Q014', 'Q015', 'Q016', 'Q017', 'Q018', 'Q019', 'Q020', 'Q021', 'Q022', 'Q023', 'Q024', 'Q025', 'Q026', 'Q027', 'Q028', 'Q029', 'Q030', 'Q031', 'Q032', 'Q033', 'Q034', 'Q035', 'Q036', 'Q037', 'Q038', 'Q039', 'Q040', 'Q041', 'Q042', 'Q043', 'Q044', 'Q045', 'Q046', 'Q047', 'Q048', 'Q049', 'Q050']

# %%
columns = []
for col in df.columns:
    columns.append(col)

print(columns)

drop_columns = [
    "NU_INSCRICAO",
    "CO_MUNICIPIO_ESC",
    "CO_UF_ESC",
    "IN_CERTIFICADO",
    "NO_ENTIDADE_CERTIFICACAO",
    "CO_UF_ENTIDADE_CERTIFICACAO",
    "SG_UF_ENTIDADE_CERTIFICACAO",
    "CO_MUNICIPIO_PROVA",
    "CO_UF_PROVA",
    "TP_PRESENCA_CN",
    "TP_PRESENCA_CH",
    "TP_PRESENCA_LC",
    "TP_PRESENCA_MT",
    "CO_PROVA_CN",
    "CO_PROVA_CH",
    "CO_PROVA_LC",
    "CO_PROVA_MT",
    "TX_RESPOSTAS_CN",
    "TX_RESPOSTAS_CH",
    "TX_RESPOSTAS_LC",
    "TX_RESPOSTAS_MT",
    "TP_LINGUA",
    "TX_GABARITO_CN",
    "TX_GABARITO_CH",
    "TX_GABARITO_LC",
    "TX_GABARITO_MT",
    "TP_STATUS_REDACAO",
    "NU_NOTA_COMP1",
    "NU_NOTA_COMP2",
    "NU_NOTA_COMP3",
    "NU_NOTA_COMP4",
    "NU_NOTA_COMP5",
    # "Q054",
    # "Q055",
    # "Q056",
    # "Q057",
    # "Q058",
    # "Q059",
    # "Q060",
    # "Q061",
    # "Q062",
    # "Q063",
    # "Q064",
    # "Q065",
    # "Q066",
    # "Q067",
    # "Q068",
    # "Q069",
    # "Q070",
    # "Q071",
    # "Q072",
    # "Q073",
    # "Q074",
    # "Q075",
    # "Q076",
]

df = df.drop(drop_columns, axis=1)
df.head()
# Out:
# ['NU_INSCRICAO', 'NU_ANO', 'TP_FAIXA_ETARIA', 'TP_SEXO', 'TP_ESTADO_CIVIL', 'TP_COR_RACA', 'TP_NACIONALIDADE', 'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO', 'IN_TREINEIRO', 'CO_MUNICIPIO_ESC', 'NO_MUNICIPIO_ESC', 'CO_UF_ESC', 'SG_UF_ESC', 'TP_DEPENDENCIA_ADM_ESC', 'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC', 'IN_CERTIFICADO', 'NO_ENTIDADE_CERTIFICACAO', 'CO_UF_ENTIDADE_CERTIFICACAO', 'SG_UF_ENTIDADE_CERTIFICACAO', 'CO_MUNICIPIO_PROVA', 'NO_MUNICIPIO_PROVA', 'CO_UF_PROVA', 'SG_UF_PROVA', 'TP_PRESENCA_CN', 'TP_PRESENCA_CH', 'TP_PRESENCA_LC', 'TP_PRESENCA_MT', 'CO_PROVA_CN', 'CO_PROVA_CH', 'CO_PROVA_LC', 'CO_PROVA_MT', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC', 'NU_NOTA_MT', 'TX_RESPOSTAS_CN', 'TX_RESPOSTAS_CH', 'TX_RESPOSTAS_LC', 'TX_RESPOSTAS_MT', 'TP_LINGUA', 'TX_GABARITO_CN', 'TX_GABARITO_CH', 'TX_GABARITO_LC', 'TX_GABARITO_MT', 'TP_STATUS_REDACAO', 'NU_NOTA_COMP1', 'NU_NOTA_COMP2', 'NU_NOTA_COMP3', 'NU_NOTA_COMP4', 'NU_NOTA_COMP5', 'NU_NOTA_REDACAO', 'Q001', 'Q002', 'Q
# ...

# %%
df.to_csv('../project/MICRODADOS_ENEM_2014_clean.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 2
#       1 df.to_csv('../project/MICRODADOS_ENEM_2014_clean.csv', index=False)
# ----> 2 print(df.columns.length)
#
# AttributeError: 'Index' object has no attribute 'length'

# %%
import geopandas as gpd

# Caminho do arquivo GeoJSON
geojson_path = "../project/geojson/br_states.json"

# Carregar o GeoJSON em um GeoDataFrame
gdf = gpd.read_file(geojson_path)

# Exibir as primeiras linhas
print(gdf.head())
# Out:
#    id  FID_Export SIGLA     Total   Homens  Mulheres   Urbana    Rural  \
# 0  AC           0    AC    557526   280983    276543   370267   187259
# 1  AL           1    AL   2822621  1378942   1443679  1919739   902882
# 2  AM           2    AM   2812557  1414367   1398190  2107222   705335
# 3  AP           3    AP    477032   239453    237579   424683    52349
# 4  BA           4    BA  13070250  6462033   6608217  8772348  4297902
#
#     TX_Alfab  FID_estado    Estado FK_macro PK_sigla  \
# 0  65.154545          -1      Acre        N       AC
# 1  59.364356          -1   Alagoas       NE       AL
# 2  72.250000          -1  Amazonas        N       AM
# 3  83.650000          -1     Amapá        N       AP
# 4  71.163373          -1     Bahia       NE       BA
#
#                                             geometry
# 0  MULTIPOLYGON (((-66.80619 -9.81446, -66.64485 ...
# 1  MULTIPOLYGON (((-35.15263 -8.91373, -35.15628 ...
# 2  MULTIPOLYGON (((-67.3259 2.02976, -67.30001 1....
# ...

# %%
import matplotlib.pyplot as plt
print(gdf.columns)
gdf.plot()
plt.show()
# Out:
# Index(['id', 'FID_Export', 'SIGLA', 'Total', 'Homens', 'Mulheres', 'Urbana',
#        'Rural', 'TX_Alfab', 'FID_estado', 'Estado', 'FK_macro', 'PK_sigla',
#        'geometry'],
#       dtype='object')

# %%
def plot_state(state_name):
    # Filtrar um estado (exemplo: "Minas Gerais")
    estado_escolhido = state_name
    gdf_estado = gdf[gdf["SIGLA"] == estado_escolhido]

    # Plotar apenas o estado escolhido
    fig, ax = plt.subplots(figsize=(6, 6))
    gdf_estado.plot(ax=ax, edgecolor="black", color="lightblue")
    plt.title(f"Mapa de {estado_escolhido}")
    plt.show()

# %%
for state in gdf["SIGLA"]:
    plot_state(state)
